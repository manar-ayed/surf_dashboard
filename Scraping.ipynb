# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def extract_meteo_surf(url) :
    
    """
    This function takes a  url an user_agent, scrapes surf forecast data from a given url page and stores 
    data points in a csv_file
    
    - output : pandas dataframe contaning the data extracted
    """
    
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # Initialize empty lists to hold the data needed :
    dates = []
    hours = []
    vagues = []
    wind_speeds = []
    wind_directions = []

    # Looping through each forecast-tab block (each block represents one day)
    forecast_tabs = soup.find_all('div', class_='forecast-tab')
    for tab in forecast_tabs:
        # Extracting the date for this tab
        date_div = tab.find('div', class_='title')
        forecast_date = date_div.find('b').text.strip() if date_div else 'N/A'

        # Extracting the hours, waves, wind speeds, and wind directions for this date
        time_divs = tab.find_all('div', class_='cell date with-border')
        for time_div in time_divs:
            hour = time_div.text.strip()
            hours.append(hour)
            dates.append(forecast_date)  # Repeat the date for each hour

        # Extracting waves (vagues)
        for wave_div in tab.find_all('div', class_='cell large waves with-border'):
            vague = wave_div.text.strip()
            vagues.append(vague)

        # Extracting wind speeds
        for wind_div in tab.select('div[class^="wind wind-color-"]'):
            wind_speed = wind_div.find('span').text.strip()
            wind_speeds.append(wind_speed)

        # Extracting wind directions
        for wind_dir_div in tab.find_all('div', class_='wind img'):
            wind_direction = wind_dir_div.find('img')['alt'] if wind_dir_div else 'N/A'
            wind_directions.append(wind_direction)

    # Creating a DataFrame with the extracted data
    wave_data = pd.DataFrame({
        'Date': dates,
        'Hour': hours,
        'Vagues': vagues,
        'Wind Speed (km/h)': wind_speeds,
        'Wind Direction': wind_directions
    })

    wave_data.to_csv('output.csv', index=False)
    return wave_data

# %%
wave_data = extract_meteo_surf('https://www.surf-report.com/meteo-surf/lacanau-s1043.html')

# %%
wave_data
# Out:
#                     Date   Hour     Vagues Wind Speed (km/h)  \
# 0   Dimanche 17 Novembre  01:00  0.3 - 0.5                22
# 1   Dimanche 17 Novembre  04:00  0.3 - 0.5                22
# 2   Dimanche 17 Novembre  07:00  0.3 - 0.4                15
# 3   Dimanche 17 Novembre  10:00  0.4 - 0.5                15
# 4   Dimanche 17 Novembre  13:00  0.4 - 0.6                 1
# 5   Dimanche 17 Novembre  16:00  0.5 - 0.7                10
# 6   Dimanche 17 Novembre  19:00  0.5 - 0.8                11
# 7   Dimanche 17 Novembre  22:00  0.6 - 0.9                14
# 8      Lundi 18 Novembre  01:00  0.6 - 1.0                21
# 9      Lundi 18 Novembre  04:00  0.7 - 1.0                12
# 10     Lundi 18 Novembre  07:00  0.7 - 1.0                12
# 11     Lundi 18 Novembre  10:00  0.7 - 1.0                 8
# 12     Lundi 18 Novembre  13:00  0.7 - 1.1                15
# 13     Lundi 18 Novembre  16:00  0.7 - 1.1                14
# 14     Lundi 18 Novembre  19:00  0.7 - 1.1                15
# 15     Lundi 18 Novembre  22:00  0.7 - 1.1                24
# 16     Mardi 19 Novembre  01:00  0.7 - 1.0                33
# 17     Mardi 19 Novembre  04:00  0.7 - 1.0                31
# 18     Mardi 19 Novembre  07:00  0.6 - 1.0                38
# 19     Mardi 19 Novembre  10:00  0.6 - 1.0                47
# 20     Mardi 19 Novembre  13:00  0.9 - 1.4                50
# 21     Mardi 19 Novembre  16:00  1.0 - 1.5                43
# 22     Mardi 19 Novembre  19:00  0.7 - 1.1                31
# 23     Mardi 19 Novembre  22:00  2.3 - 3.4                19
# 24  Mercredi 20 Novembre  01:00  2.2 - 3.3                13
# 25  Mercredi 20 Novembre  04:00  1.8 - 2.7                14
# 26  Mercredi 20 Novembre  07:00  1.6 - 2.3                 3
# 27  Mercredi 20 Novembre  10:00  2.0 - 3.0                 5
# 28  Mercredi 20 Novembre  13:00  2.0 - 3.1                 9
# 29  Mercredi 20 Novembre  16:00  1.9 - 2.8                17
# 30  Mercredi 20 Novembre  19:00  1.7 - 2.6                30
# 31  Mercredi 20 Novembre  22:00  1.6 - 2.4                22
# 32     Jeudi 21 Novembre  01:00  1.4 - 2.1                19
# 33     Jeudi 21 Novembre  04:00  1.3 - 1.9                 9
# 34     Jeudi 21 Novembre  07:00  1.2 - 1.8                17
# 35     Jeudi 21 Novembre  10:00  0.4 - 0.6                20
# 36     Jeudi 21 Novembre  13:00  0.6 - 0.9                44
# 37     Jeudi 21 Novembre  16:00  0.5 - 0.8                52
# 38     Jeudi 21 Novembre  19:00  1.0 - 1.6                44
# 39     Jeudi 21 Novembre  22:00  2.7 - 4.1                18
# 40  Vendredi 22 Novembre  01:00  2.4 - 3.6                16
# 41  Vendredi 22 Novembre  04:00  2.0 - 3.0                13
# 42  Vendredi 22 Novembre  07:00  1.7 - 2.5                14
# 43  Vendredi 22 Novembre  10:00  1.5 - 2.2                13
# 44  Vendredi 22 Novembre  13:00  1.4 - 2.0                14
# 45  Vendredi 22 Novembre  16:00  1.5 - 2.2                14
# 46  Vendredi 22 Novembre  19:00  1.4 - 2.1                43
# 47  Vendredi 22 Novembre  22:00  1.3 - 2.0                37
# 48    Samedi 23 Novembre  01:00  1.2 - 1.8                32
# 49    Samedi 23 Novembre  04:00  1.1 - 1.6                31
# 50    Samedi 23 Novembre  07:00  0.9 - 1.4                32
# 51    Samedi 23 Novembre  10:00  0.8 - 1.2                34
# 52    Samedi 23 Novembre  13:00  0.7 - 1.1                34
# 53    Samedi 23 Novembre  16:00  0.7 - 1.0                11
# 54    Samedi 23 Novembre  19:00  0.6 - 0.9                14
# 55    Samedi 23 Novembre  22:00  0.6 - 0.9                11
#
#                        Wind Direction
# 0    Orientation vent Nord Nord Ouest
# 1               Orientation vent Nord
# 2           Orientation vent Nord Est
# 3           Orientation vent Nord Est
# 4    Orientation vent Nord Nord Ouest
# 5              Orientation vent Ouest
# 6          Orientation vent Sud Ouest
# 7        Orientation vent Sud Sud Est
# 8              Orientation vent Ouest
# 9       Orientation vent Est Nord Est
# 10           Orientation vent Sud Est
# 11       Orientation vent Sud Sud Est
# 12  Orientation vent Ouest Nord Ouest
# 13             Orientation vent Ouest
# 14             Orientation vent Ouest
# 15   Orientation vent Ouest Sud Ouest
# 16   Orientation vent Ouest Sud Ouest
# 17   Orientation vent Ouest Sud Ouest
# 18   Orientation vent Ouest Sud Ouest
# 19   Orientation vent Ouest Sud Ouest
# 20             Orientation vent Ouest
# 21  Orientation vent Ouest Nord Ouest
# 22  Orientation vent Ouest Nord Ouest
# 23              Orientation vent Nord
# 24      Orientation vent Est Nord Est
# 25      Orientation vent Est Nord Est
# 26     Orientation vent Nord Nord Est
# 27           Orientation vent Sud Est
# 28       Orientation vent Sud Sud Est
# 29       Orientation vent Sud Sud Est
# 30   Orientation vent Ouest Sud Ouest
# 31  Orientation vent Ouest Nord Ouest
# 32  Orientation vent Ouest Nord Ouest
# 33           Orientation vent Sud Est
# 34           Orientation vent Sud Est
# 35           Orientation vent Sud Est
# 36   Orientation vent Ouest Sud Ouest
# 37   Orientation vent Ouest Sud Ouest
# 38             Orientation vent Ouest
# 39   Orientation vent Nord Nord Ouest
# 40          Orientation vent Nord Est
# 41               Orientation vent Est
# 42               Orientation vent Est
# 43           Orientation vent Sud Est
# 44           Orientation vent Sud Est
# 45       Orientation vent Est Sud Est
# 46             Orientation vent Ouest
# 47             Orientation vent Ouest
# 48   Orientation vent Ouest Sud Ouest
# 49   Orientation vent Ouest Sud Ouest
# 50   Orientation vent Ouest Sud Ouest
# 51   Orientation vent Ouest Sud Ouest
# 52   Orientation vent Ouest Sud Ouest
# 53        Orientation vent Nord Ouest
# 54          Orientation vent Nord Est
# 55      Orientation vent Est Nord Est

# %%
wave_data.to_csv('./wave_data.csv', index=False)
